# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/dm-fedorov/python_basic/master/data/vkontakte_group_01_2016-08-01_2020-03-15.csv")
df.head()
# Out:
#          Дата  Критерий Парам. №1 Парам. №2  Значение
# 0  15.03.2020     views       NaN       NaN         4
# 1  15.03.2020  visitors       NaN       NaN         3
# 2  15.03.2020    gender         М       NaN         3
# 3  15.03.2020       age     24-27       NaN         1
# 4  15.03.2020       age     30-35       NaN         2

# %%
c = pd.get_dummies(df, columns=['Критерий'])
views = c[['Дата', 'Значение']][c['Критерий_views'] == 1]

# %%
from datetime import datetime
def toData(row):
    return datetime.strptime(row['Дата'], '%d.%m.%Y')

# %%
views['Дата'] = views.apply(toData, axis=1)
views['Дата'] = views['Дата'].dt.strftime('%Y') 
viewsYear = views.groupby(['Дата'])['Значение'].sum()

# %%
plt.title('Статистика посещений за год')
graph = plt.gca()
graph.tick_params(axis='x')
graph.tick_params(axis='y')
viewsYear.plot()
plt.show()

# %%
audM = c[['Дата','Значение']][c['Критерий_reach'] == 1]
audM['Дата'] = audM.apply(toData, axis=1)
audM['Дата'] = audM['Дата'].dt.strftime('%Y-%m')
audMonth = audM.groupby(['Дата'])['Значение'].sum()

# %%
plt.title('Статистика посещений за месяц')
audMonth.plot()
plt.show()

# %%
femSX = c[['Значение','Парам. №1']][c['Критерий_gender'] == 1]
fem = femSX.groupby(['Парам. №1'])

# %%
m = femSX[femSX['Парам. №1'] == "М"].count()
w = femSX[femSX['Парам. №1'] == "Ж"].count()
allWM = w + m
man = round(m/allWM,5) * 100
woman = round(w/allWM,5) * 100

# %%
age = c[['Парам. №1', 'Значение']][c['Критерий_age'] == 1]
agePlus = age.groupby(['Парам. №1'])['Значение'].sum()
agePlus.plot.bar()

# %%
country = c[['Парам. №1','Значение']][c['Критерий_countries'] == 1]
countryIn = country.groupby(['Парам. №1'])['Значение'].sum()
countryIn[:10].plot.bar()

# %%
obratSV = c[['Дата','Парам. №1','Значение']][c['Критерий_feedback'] == 1]
obratSV['Дата'] = obratSV.apply(toData, axis = 1)
obratSV['Дата'] = obratSV['Дата'].dt.strftime('%Y-%m')
obratSV['Парам. №1'].value_counts()
# Out:
# Нравится              683
# Рассказали друзьям    291
# Комментарии            91
# Упоминания              1
# Name: Парам. №1, dtype: int64

# %%
like = obratSV[obratSV['Парам. №1'] == 'Нравится']
likes = like.groupby(['Дата'])['Значение'].sum()
likes.plot()

# %%
rep = obratSV[obratSV['Парам. №1'] == 'Рассказали друзьям']
reps = rep.groupby(['Дата'])['Значение'].sum()
reps.plot()

# %%
com = obratSV[obratSV['Парам. №1'] == 'Комментарии']
coms = com.groupby(['Дата'])['Значение'].sum()
coms.plot()

# %%
countryIn[countryIn > 100].plot.bar()
